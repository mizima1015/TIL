# %% [markdown]
# ## Google Drive 연동

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## JAVA 설치
# - JVM 실행 위해서는 JAVA 설치 필수

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %% [markdown]
#  ## Spark 설치
#  - 기존 : Web Link를 통해서 다운 후, 압축파일 불기
#  - 오늘 : 구글 드라이브에서 파일 가져오기

# %%
# %cd /content/drive/MyDrive/멀티캠퍼스/spark
# Out:
# /content/drive/MyDrive/멀티캠퍼스/spark

# %%
# !pwd
# Out:
# /content/drive/MyDrive/멀티캠퍼스/spark

# %%
# !ls
# Out:
# spark-3.1.1-bin-hadoop2.7.tgz

# %%
# !cp -r spark-3.1.1-bin-hadoop2.7.tgz /content

# %%
# %cd /content/
# Out:
# /content

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# drive  sample_data  spark-3.1.1-bin-hadoop2.7.tgz

# %%
# !tar xf spark-3.1.1-bin-hadoop2.7.tgz > /dev/null

# %% [markdown]
# ## 환경변수 설정
# - 일반적으로 vi 편집기를 열어서 작업
# - 구글코랩 : os 라이브러리 사용해서 환경변수 지정

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.1-bin-hadoop2.7"

# %% [markdown]
# ## PySpark 설치

# %%
# !pip install -q pyspark==3.1.1
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.3/212.3 MB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.6/198.6 kB 16.1 MB/s eta 0:00:00
#   Building wheel for pyspark (setup.py) ... done

# %% [markdown]
# ## Ngrok 설정
# - 회원가입해서 Token을 받는다.
# - 링크 : https://ngrok.com/

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip &> /dev/null
# !unzip ngrok-stable-linux-amd64.zip &> /dev/null

# %%
# !pip install pyngrok
# Out:
# Collecting pyngrok
#   Downloading pyngrok-7.0.0.tar.gz (718 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 718.7/718.7 kB 9.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.1)
# Building wheels for collected packages: pyngrok
#   Building wheel for pyngrok (setup.py) ... done
#   Created wheel for pyngrok: filename=pyngrok-7.0.0-py3-none-any.whl size=21129 sha256=c898b838d75f3bb61b8f47d88139264ec8ef78e1c472fb2aa02abd8a34d06c04
#   Stored in directory: /root/.cache/pip/wheels/60/29/7b/f64332aa7e5e88fbd56d4002185ae22dcdc83b35b3d1c2cbf5
# Successfully built pyngrok
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.0.0

# %%
# !./ngrok authtoken 2X9PpF2DqMesfWaMzGuOeMfHNxC_2W95ibFm3gAcfZbtJ2DCa
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %% [markdown]
# ## 테스트

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('mulCamp28').config('spark.ui.port','4050').getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://e61ba6d63f91:4050">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>mulCamp28</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
get_ipython().system_raw('./ngrok http 4050 &')
# !curl -s http://localhost:4040/api/tunnels
# Out:
# {"tunnels":[{"name":"command_line","uri":"/api/tunnels/command_line","public_url":"https://7377-34-74-233-149.ngrok-free.app","proto":"https","config":{"addr":"http://localhost:4050","inspect":true},"metrics":{"conns":{"count":0,"gauge":0,"rate1":0,"rate5":0,"rate15":0,"p50":0,"p90":0,"p95":0,"p99":0},"http":{"count":0,"rate1":0,"rate5":0,"rate15":0,"p50":0,"p90":0,"p95":0,"p99":0}}},{"name":"command_line (http)","uri":"/api/tunnels/command_line%20%28http%29","public_url":"http://7377-34-74-233-149.ngrok-free.app","proto":"http","config":{"addr":"http://localhost:4050","inspect":true},"metrics":{"conns":{"count":0,"gauge":0,"rate1":0,"rate5":0,"rate15":0,"p50":0,"p90":0,"p95":0,"p99":0},"http":{"count":0,"rate1":0,"rate5":0,"rate15":0,"p50":0,"p90":0,"p95":0,"p99":0}}}],"uri":"/api/tunnels"}

# %% [markdown]
# ## Spark 종료

# %%
spark.stop()
